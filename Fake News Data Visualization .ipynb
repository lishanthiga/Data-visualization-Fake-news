# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("fakenews.csv")
data
# Out:
#                                                    text  label
# 0     Get the latest from TODAY Sign up for our news...      1
# 1     2d  Conan On The Funeral Trump Will Be Invited...      1
# 2     It’s safe to say that Instagram Stories has fa...      0
# 3     Much like a certain Amazon goddess with a lass...      0
# 4     At a time when the perfect outfit is just one ...      0
# ...                                                 ...    ...
# 4981  The storybook romance of WWE stars John Cena a...      0
# 4982  The actor told friends he’s responsible for en...      0
# 4983  Sarah Hyland is getting real.  The Modern Fami...      0
# 4984  Production has been suspended on the sixth and...      0
# 4985  A jury ruled against Bill Cosby in his sexual ...      0
#
# [4986 rows x 2 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of                                                    text  label
# 0     Get the latest from TODAY Sign up for our news...      1
# 1     2d  Conan On The Funeral Trump Will Be Invited...      1
# 2     It’s safe to say that Instagram Stories has fa...      0
# 3     Much like a certain Amazon goddess with a lass...      0
# 4     At a time when the perfect outfit is just one ...      0
# ...                                                 ...    ...
# 4981  The storybook romance of WWE stars John Cena a...      0
# 4982  The actor told friends he’s responsible for en...      0
# 4983  Sarah Hyland is getting real.  The Modern Fami...      0
# 4984  Production has been suspended on the sixth and...      0
# 4985  A jury ruled against Bill Cosby in his sexual ...      0
#
# [4986 rows x 2 columns]>

# %%
data.dropna(inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['label'], test_size=0.2, random_state=42)

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='label', data=data)
plt.title('Distribution of Labels')
plt.xlabel('Label')
plt.ylabel('Count')
plt.show()

# %%
text_lengths = data['text'].apply(len)
plt.figure(figsize=(8, 6))
sns.histplot(text_lengths, bins=30, kde=True)
plt.title('Distribution of Text Lengths')
plt.xlabel('Text Length')
plt.ylabel('Count')
plt.show()

# %%
pip install wordcloud
# Out:
# ...
#      ------------------------------------ 300.0/300.0 kB 303.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

# %%
plt.figure(figsize=(10, 8))
wc = WordCloud(width=800, height=400, max_words=200).generate(" ".join(data[data['label'] == 0]['text']))
plt.imshow(wc, interpolation='bilinear')
plt.title('Word Cloud for Class 0')
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(10, 8))
wc = WordCloud(width=800, height=400, max_words=200).generate(" ".join(data[data['label'] == 1]['text']))
plt.imshow(wc, interpolation='bilinear')
plt.title('Word Cloud for Class 1')
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='label', y=data['text'].apply(len))
plt.title('Text Length by Label')
plt.xlabel('Label')
plt.ylabel('Text Length')
plt.show()

# %%
plt.figure(figsize=(8, 6))
labels = ['Label 0', 'Label 1']
sizes = data['label'].value_counts()
colors = ['lightblue', 'lightgreen']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Labels')
plt.axis('equal')
plt.show()
